# %%
import pandas as pd
import re

# %%
pd.options.display.max_columns=None

# %%
df_data_kaggle = pd.read_csv("../archivos_originales/_data_remaning_kaggle.csv")

# %%
df_data_kaggle.head(2)
# Out:
#    Unnamed: 0  index                                         Q18_Part_1  \
# 0           0      0  General purpose image/video tools (PIL, cv2, s...
# 1           1      1                                                NaN
#
#   Q18_Part_2 Q18_Part_3 Q18_Part_4 Q18_Part_5 Q18_Part_6 Q18_OTHER  \
# 0        NaN        NaN        NaN        NaN        NaN       NaN
# 1        NaN        NaN        NaN        NaN        NaN       NaN
#
#                                           Q19_Part_1 Q19_Part_2 Q19_Part_3  \
# 0  Word embeddings/vectors (GLoVe, fastText, word...        NaN        NaN
# 1                                                NaN        NaN        NaN
#
#   Q19_Part_4 Q19_Part_5 Q19_OTHER Q27_A_Part_1 Q27_A_Part_2  \
# 0        NaN        NaN       NaN          NaN          NaN
# 1        NaN        NaN       NaN          NaN          NaN
#
#                     Q27_A_Part_3 Q27_A_Part_4 Q27_A_Part_5 Q27_A_Part_6  \
# ...

# %%
def seleccionar_columnas(df, patron):
    columnas = df.columns
    lista_columnas = ["index"]
    for col in columnas:
        elemento_col = re.findall(patron, col)
        if len(elemento_col) ==1:
            lista_columnas.append(elemento_col[0])
    df = df[lista_columnas]
    return df

# %%
df_xml = pd.read_xml("../archivos_originales/_data_xml_clean(1).xml")

# %%
df_xml.head()
# Out:
#    level_0  index  time    age gender
# 0        0      0   910  50-54    Man
# 1        1      1   784  50-54    Man
# 2        2      2   924  22-24    Man
# 3        3      3   575  45-49    Man
# 4        4      4   781  45-49    Man

# %%
df_xml = seleccionar_columnas(df_xml, "age|gender")

# %%
df_xml.head()
# Out:
#    index    age gender
# 0      0  50-54    Man
# 1      1  50-54    Man
# 2      2  22-24    Man
# 3      3  45-49    Man
# 4      4  45-49    Man

# %%
df_xml.duplicated().sum()
# Out:
# 0

# %%
df_txt = pd.read_csv("../archivos_originales/_data_txt_clean.txt", sep = ";")

# %%
df_txt.sample(3)
# Out:
#        index      Q3                 Q4                      Q5           Q6  \
# 14609  14609  Mexico  Bachelor’s degree            Statistician  10-20 years
# 13475  13475   Egypt  Bachelor’s degree  Currently not employed   5-10 years
# 24832  24832   Japan    Master’s degree            Statistician    1-3 years
#
#            Q8                                                Q11        Q13  \
# 14609  Python                                           A laptop      Never
# 13475  Python                                           A laptop      Never
# 24832  Python  A cloud computing platform (AWS, Azure, GCP, h...  2-5 times
#
#              Q15                  Q20             Q21  Q22  \
# 14609   < 1 year  Academics/Education  0-49 employees  1-2
# 13475  1-2 years                  NaN             NaN  NaN
# 24832   < 1 year        Marketing/CRM  0-49 employees  1-2
#
#                                                      Q23            Q25  \
# ...

# %%
df_txt.duplicated().sum()
# Out:
# 0

# %%
df_txt.columns
# Out:
# Index(['index', 'Q3', 'Q4', 'Q5', 'Q6', 'Q8', 'Q11', 'Q13', 'Q15', 'Q20',
#        'Q21', 'Q22', 'Q23', 'Q25', 'Q26', 'Q33', 'Q35', 'Q41', 'Q7', 'Q9',
#        'Q12', 'Q14', 'Q16', 'Q17', 'Q24', 'Q32', 'Q34'],
#       dtype='object')

# %%
df_txt = seleccionar_columnas(df_txt, "Q3[^2]|Q3$|Q41|Q4|Q5|Q6|Q7|Q8|Q9|Q1[^1|^3|^2]|Q20|Q2[^2|^6]")

# %%
df_txt.head(1)
# Out:
#    index     Q3                 Q4     Q5          Q6      Q8         Q15  \
# 0      0  India  Bachelor’s degree  Other  5-10 years  Python  5-10 years
#
#                          Q20               Q21                            Q23  \
# 0  Manufacturing/Fabrication  50-249 employees  No (we do not use ML methods)
#
#              Q25  Q33  Q35                                                Q41  \
# 0  25,000-29,999  NaN  NaN  Local development environments (RStudio, Jupyt...
#
#           Q7            Q9                                                Q14  \
# 0  Python, R   Vim / Emacs   Matplotlib ,Seaborn ,Ggplot / ggplot2 ,Shiny ...
#
#                                  Q16  \
# 0  Scikit-learn , TensorFlow ,Caret
#
#                                                  Q17  \
# 0  Linear or Logistic Regression, Decision Trees ...
#
#                                                  Q24    Q34
# 0   None of these activities are an important par...   None

# %%
df_total = df_txt.merge(df_xml, on ="index")

df_total.head(1)
# Out:
#    index     Q3                 Q4     Q5          Q6      Q8         Q15  \
# 0      0  India  Bachelor’s degree  Other  5-10 years  Python  5-10 years
#
#                          Q20               Q21                            Q23  \
# 0  Manufacturing/Fabrication  50-249 employees  No (we do not use ML methods)
#
#              Q25  Q33  Q35                                                Q41  \
# 0  25,000-29,999  NaN  NaN  Local development environments (RStudio, Jupyt...
#
#           Q7            Q9                                                Q14  \
# 0  Python, R   Vim / Emacs   Matplotlib ,Seaborn ,Ggplot / ggplot2 ,Shiny ...
#
#                                  Q16  \
# 0  Scikit-learn , TensorFlow ,Caret
#
#                                                  Q17  \
# 0  Linear or Logistic Regression, Decision Trees ...
#
#                                                  Q24    Q34    age gender
# ...

# %%
df_total =df_total.drop("index", axis = 1)

# %%
df_total[df_total.duplicated()]
# Out:
#              Q3                 Q4                      Q5  \
# 8559      India  Bachelor’s degree                 Student
# 9418   Pakistan  Bachelor’s degree                 Student
# 13765     Egypt  Bachelor’s degree  Currently not employed
# 14908     India  Bachelor’s degree                 Student
# 14979     India  Bachelor’s degree                 Student
# 19434     India  Bachelor’s degree                 Student
# 20153     India  Bachelor’s degree                 Student
# 23693     India  Bachelor’s degree                 Student
# 24488     India  Bachelor’s degree                 Student
# 25807     Japan    Master’s degree  Currently not employed
#
#                               Q6      Q8  \
# 8559   I have never written code     NaN
# 9418                   < 1 years  Python
# 13765                  < 1 years  Python
# 14908                  1-3 years  Python
# 14979                  < 1 years  Python
# 19434                  < 1 years  Python
# ...

# %%
df_total.duplicated().sum()
# Out:
# 10

# %%
df_total.to_csv("../archivos_editados/df_completo.csv")
